# %% [markdown]
# # Projet Stratégies d'Investissement Alternatives et Quantitatives
# ## Jérémy Bellina, Joël Zhu

# %% [markdown]
# # Set up all packages and information

# %%
# import needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
# load the csv data
crypto_prices = pd.read_csv("crypto_prices.csv", parse_dates=[0])
crypto_prices.set_index('date', inplace=True)

# %%
# create rebalancing dates array
rebalancing_dates = pd.date_range(start = "2018-04-01", end = "2020-05-01", freq = pd.DateOffset(months=1, day = 1))
formatted_dates = pd.date_range(start = "2018-04-01", end = "2020-05-26")

# %%
# horizon
horizon = 14
# Initial value of protfolio
initial_value = 100000

# %% [markdown]
# # Main algorithm

# %%
def compute_return(start_date, end_date, data):
    return (data.loc[end_date] - data.loc[start_date])/data.loc[start_date]

# %%
def update_value(date, portfolios, crypto_prices):
    value = 0
    for portfolio in portfolios:
        for item in portfolio:
            value += item[1] * crypto_prices.loc[date, item[0]]
    return value

# %%
def get_value_equally_weighted(values):
    return values[len(values) - 1]

# %%
def get_value_long_short(values):
    return 1000

# %%
 def backtest_portfolio(initial_value, horizon, formatted_dates, rebalancing_dates, data, update_composition, get_value):
    values = [initial_value]
    for date in formatted_dates:
        if date in rebalancing_dates:
            start_date = str(date.date() - pd.to_timedelta(horizon, unit='d'))
            end_date = str(date.date())
            portfolios = update_composition(start_date, end_date, data, get_value(values))
        values.append(update_value(date, portfolios, data)) 

    return values[1:]

# %% [markdown]
# # Portfolio composition strategies

# %% [markdown]
# Creates portfolio long on all crypto currencies **equally weighted**

# %%
def update_composition_equally_weighted(start_date, end_date, data, value):
    portfolios = [[] for _ in range(5)]
    returns = compute_return(start_date, end_date, crypto_prices)
    # We sort those returns
    sorted_returns = returns.sort_values(ascending=False)
    #We create the 5 portfolios
    for index_portfolio in range (5):
        for name in sorted_returns.iloc[(10 * index_portfolio):(10 * (index_portfolio + 1))].index:
            portfolios[index_portfolio].append((name, value / 50 / data.loc[end_date, name]))
    return portfolios

# %% [markdown]
# Creates a portfolio **long on best returns** crypto currencies and **short on lowest returns** ones

# %%
def update_composition_long_short(start_date, end_date, data, exposition):
    portfolios = [[] for _ in range(2)]
    returns = compute_return(start_date, end_date, crypto_prices)
    # We sort those returns
    sorted_returns = returns.sort_values(ascending=False)
    #We create the 2 portfolios
    for name in sorted_returns.iloc[40:50].index:
        portfolios[1].append((name, - exposition / 10 / data.loc[end_date, name]))
    for name in sorted_returns.iloc[0:10].index:
        portfolios[0].append((name, exposition / 10 / data.loc[end_date, name]))
            
    return portfolios

# %% [markdown]
# # Plot of portfolios values

# %%
ptf_values = backtest_portfolio(initial_value, horizon, formatted_dates, rebalancing_dates, crypto_prices, update_composition_equally_weighted, get_value_equally_weighted)
plt.figure(figsize=(12, 6))
plt.title("Portfolio value")
plt.xlabel("Date")
plt.ylabel("Value ($)")
plt.plot(formatted_dates, ptf_values)

# %%
ptf_values = backtest_portfolio(initial_value, horizon, formatted_dates, rebalancing_dates, crypto_prices, update_composition_long_short, get_value_long_short)
plt.figure(figsize=(12, 6))
plt.title("Portfolio value")
plt.xlabel("Date")
plt.ylabel("Value ($)")
plt.plot(formatted_dates, ptf_values)
